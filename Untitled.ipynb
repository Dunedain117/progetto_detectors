# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("new.csv", sep=" ")
data = df.to_numpy()

# %%
#data[:,1]+=150

# %%
#print(data[:,0])
x=data[:,1]+150.
r = np.sqrt(x**2 + data[:,2]**2 +data[:,3]**2)
i = 0
de = data[:,5]
# for element in data[:,5]:
#     if i == 0:
#         de.append(element/r[0])
#     else:
#         de.append(element/(r[i]-r[i-1]))
#     i = i+1
plt.plot(r,de,".")
#plt.xlim(0,300)

# %%
r
# Out:
# array([150.        , 147.        , 144.00000067, 141.0000091 ,
#        138.0000257 , 135.00005105, 132.00008095, 129.00010247,
#        126.00014399, 123.00020235, 120.00028356, 117.00038974,
#        114.00050675, 111.00062599, 108.00077307, 105.00094309,
#        102.00111384,  99.00131182,  96.00154265,  93.00178622,
#         90.00189491,  87.00211782,  84.00243069,  81.00297864,
#         78.00375408,  75.00453494,  72.00543586,  69.00659665,
#         66.00798244,  63.00905932,  60.01032025,  57.01158557,
#         54.01314663,  51.01442566,  48.0160455 ,  45.01749359,
#         42.01922079,  39.02162216,  36.02559945,  33.02991983,
#         30.03585085,  27.04448254,  24.05423871,  21.06962268,
#         18.09005252,  15.31708197,  15.11964616,  12.66963693,
#         12.18181021,  10.00298455,   9.28222495,   7.46684672,
#          6.49532909,   5.08429936,   4.04634403,   3.26570054,
#          2.91886896,   2.90945012,   3.14739575,   3.60408102,
# ...
